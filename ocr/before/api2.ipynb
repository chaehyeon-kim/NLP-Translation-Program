# %%
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus
import urllib
import requests
import json
import pandas as pd

# %%
url = ('http://koreanfood.rda.go.kr/kfi/openapi/service?apiKey=20210120212110KNXI4G90WXDGKJCP2Z&serviceType=AA002&nowPage=1&pageSize=500&fdGrupp=&fdNm=')

# %%
req = urllib.request.Request(url)

response_body = urlopen(req).read() # get bytes data
data = json.loads(response_body) # convert bytes data to json data
print(data)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print(data['service'])
print(data['service']['list'])
print(data['service']['list'][0])

print(data['service']['list'][9]['irdnt'])
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
items = data['service']['list'][:]
#items.remove({})

for item in items:
  group = item["fdGrupp"]
  name = item["fdNm"]
  ingredient = item["irdnt"]
  foodlist = {'Group': group, 'Name': name, 'Ingredient': ingredient}
  json.dumps({'result': 'success'})

#db.movies.insert_one(movie)
foodlist
# Out:
# {'Group': 'null',
#  'Name': '목화씨, 구운것',
#  'Ingredient': [{'irdntSeNm': '일반성분',
#    'irdnttcket': [{'irdntNm': '에너지',
#      'irdntEngNm': 'ENERC',
#      'contInfo': '506',
#      'irdntUnitNm': '㎉'},
#     {'irdntNm': '수분',
#      'irdntEngNm': 'WATER',
#      'contInfo': '4.65',
#      'irdntUnitNm': 'g'},
#     {'irdntNm': '단백질',
#      'irdntEngNm': 'PROCNP',
#      'contInfo': '32.59',
#      'irdntUnitNm': 'g'},
#     {'irdntNm': '지질',
#      'irdntEngNm': 'FAT',
#      'contInfo': '36.29',
#      'irdntUnitNm': 'g'},
#     {'irdntNm': '회분',
#      'irdntEngNm': 'ASH',
#      'contInfo': '4.58',
#      'irdntUnitNm': 'g'},
#     {'irdntNm': '탄수화물',
#      'irdntEngNm': 'CHOTDF',
#      'contInfo': '21.9',
#      'irdntUnitNm': 'g'},
#     {'irdntNm': '총 당류',
#      'irdntEngNm': 'SUGAR',
#      'contInfo': '-',
#      'irdntUnitNm': 'g'},
#     {'irdntNm': '자당',
#      'irdntEngNm': 'SUCS',
#      'contInfo': '-',
#      'irdntUnitNm': 'g'},
#     {'irdntNm': '포도당',
# ...

# %%
from pandas.io.json import json_normalize

# %%
body = data['service']['list']
#body

# %%
df = json_normalize(data['service']['list'])
df.count()
df.head(100)
# Out:
# C:\Users\chaehyeon\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#     index        fdCode fdGrupp              fdNm  \
# 0     116  A0170010009a    null            과자, 건빵
# 1     123  A0170060169a    null           과자, 김전병
# 2     128  A0170090219a    null         과자, 대추꿀약과
# 3     145  A0170180009j    null  과자, 마카로니 과자, 튀긴것
# 4     117  A0170020139a    null         과자, 만주, 밤
# ..    ...           ...     ...               ...
# 95     43  A008030A030a    null  멥쌀, 하이아미, 백미, 생것
# 96     44  A008031A030a    null   멥쌀, 향미벼, 백미, 생것
# 97     45  A008032A030a    null   멥쌀, 호주산, 백미, 생것
# 98     51  A008037A030a    null   멥쌀, 호품벼, 백미, 생것
# 99     52  A008037A060a    null   멥쌀, 호품벼, 현미, 생것
#
#                                 fdEngNm originNm examinYear  \
# 0                      Snack, Hard tack    농촌진흥청         13
# ...

# %%
df['fdNm']
# Out:
# 0                   과자, 건빵
# 1                  과자, 김전병
# 2                과자, 대추꿀약과
# 3         과자, 마카로니 과자, 튀긴것
# 4                과자, 만주, 밤
#               ...
# 495             마가목 열매, 생것
# 496                 마름, 생것
# 497    마카다미아넛, 조미, 볶은것(기름)
# 498                머루씨, 생것
# 499               목화씨, 구운것
# Name: fdNm, Length: 500, dtype: object
